# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from skimage import data, io, color
from skimage.restoration.inpaint import inpaint_biharmonic

# %%
image_with_logo = plt.imread(
    '/Users/juansantateresagomez/Desktop/Image_Processing/Image Processing with Python course exercise dataset/chapter 3/4.2.06_w_logo_2_2.png')

# %%
io.imshow(image_with_logo)

# %% [markdown]
# Creating mask

# %%
mask = np.zeros(image_with_logo.shape[:-1])
mask.shape
# Out:
# (296, 512)

# %%
mask[210:272, 360:425]= 1

# %%
image_removing_logo = inpaint_biharmonic(image_with_logo, mask, multichannel=True)

# %%
io.imshow(image_removing_logo)

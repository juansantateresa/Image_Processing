# %%
import pandas as pd
import numpy as np
from skimage import data,color, io
import matplotlib.pyplot as plt

# %%
from skimage.filters import try_all_threshold

# %%
fruits_image = plt.imread('Image Processing with Python course exercise dataset/chapter 1/fruits-2.jpg')
io.imshow(fruits_image)

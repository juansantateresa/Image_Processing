# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from skimage.transform import rotate, rescale
from skimage import data, color, io

# %%
image_cat = plt.imread('Image Processing with Python course exercise dataset/chapter 2/image_cat.jpg')
io.imshow(image_cat)

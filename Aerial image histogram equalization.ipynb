# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from skimage import data,io,color
from skimage import exposure
from skimage.color import rgb2gray

# %%
aerial_image = plt.imread('Image Processing with Python course exercise dataset/chapter 2/image_aerial.tiff')

# %%
io.imshow(aerial_image)

# %%
image_equ = exposure.equalize_hist(aerial_image)

# %%
io.imshow(image_equ)

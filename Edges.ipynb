# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from skimage import data, color, io
from skimage.feature import canny

# %%
edges = plt.imread(
'/Users/juansantateresagomez/Desktop/Image_Processing/Image Processing with Python course exercise dataset/chapter 4/toronjas.jpg')

# %%
plt.imshow(edges
          )

# %%
edges = color.rgb2gray(edges)

# %%
canny_edges = canny(edges)

# %%
plt.imshow(canny_edges)

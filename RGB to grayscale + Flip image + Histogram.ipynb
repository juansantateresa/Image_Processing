# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from skimage import data,color,io

# %%
img = io.imread('Image Processing with Python course exercise dataset/chapter 1/rocket.png')
io.imshow(img)

# %%
def show_image(image, title='image'):
    img = io.imread(image)
    io.imshow(img)

# %%
show_image('Image Processing with Python course exercise dataset/chapter 1/rocket.png', title='rocket')

# %%
rocket
# Out:
# array([[[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  7,  18,  36]],
#
#        [[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        [[ 18,  34,  59],
#         [ 18,  34,  59],
#         [ 18,  34,  60],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        ...,
#
#        [[ 27,  28,  32],
#         [ 29,  29,  37],
#         [ 20,  24,  36],
#         ...,
#         [136, 106,  82],
#         [186, 136,  85],
#         [173, 119,  81]],
#
#        [[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 30,  34,  46],
#         ...,
#         [103,  67,  45],
#         [ 97,  61,  27],
#         [ 76,  49,  20]],
#
#        [[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 40,  46,  60],
# ...

# %%
rocket = data.rocket()

# %%
rocket
# Out:
# array([[[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  7,  18,  36]],
#
#        [[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        [[ 18,  34,  59],
#         [ 18,  34,  59],
#         [ 18,  34,  60],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        ...,
#
#        [[ 27,  28,  32],
#         [ 29,  29,  37],
#         [ 20,  24,  36],
#         ...,
#         [136, 106,  82],
#         [186, 136,  85],
#         [173, 119,  81]],
#
#        [[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 30,  34,  46],
#         ...,
#         [103,  67,  45],
#         [ 97,  61,  27],
#         [ 76,  49,  20]],
#
#        [[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 40,  46,  60],
# ...

# %%
gray_scaled_rocket = color.rgb2gray(rocket)

# %%
gray_scaled_rocket.shape
# Out:
# (427, 640)

# %%
io.imshow(gray_scaled_rocket)

# %%
rocket_vertical_flip = np.flipud(rocket)

# %%
rocket_vertical_flip
# Out:
# array([[[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 40,  46,  60],
#         ...,
#         [ 82,  53,  37],
#         [ 79,  50,  32],
#         [ 83,  61,  37]],
#
#        [[ 26,  27,  31],
#         [ 29,  32,  39],
#         [ 30,  34,  46],
#         ...,
#         [103,  67,  45],
#         [ 97,  61,  27],
#         [ 76,  49,  20]],
#
#        [[ 27,  28,  32],
#         [ 29,  29,  37],
#         [ 20,  24,  36],
#         ...,
#         [136, 106,  82],
#         [186, 136,  85],
#         [173, 119,  81]],
#
#        ...,
#
#        [[ 18,  34,  59],
#         [ 18,  34,  59],
#         [ 18,  34,  60],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        [[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
#         ...,
#         [  8,  19,  37],
#         [  8,  19,  37],
#         [  8,  19,  37]],
#
#        [[ 17,  33,  58],
#         [ 17,  33,  58],
#         [ 17,  33,  59],
# ...

# %%
io.imshow(rocket_vertical_flip)

# %%
red_channel = rocket[:,:,0]

# %%
red_channel
# Out:
# array([[ 17,  17,  17, ...,   8,   8,   7],
#        [ 17,  17,  17, ...,   8,   8,   8],
#        [ 18,  18,  18, ...,   8,   8,   8],
#        ...,
#        [ 27,  29,  20, ..., 136, 186, 173],
#        [ 26,  29,  30, ..., 103,  97,  76],
#        [ 26,  29,  40, ...,  82,  79,  83]], dtype=uint8)

# %%
plt.hist(red_channel.ravel(), bins=256)
# Out:
# (array([ 128.,   59.,   65.,   82.,   92.,  114.,  137.,  185.,  291.,
#          595.,  767., 1061., 1037., 1261., 1403., 1475., 1996., 2071.,
#         2508., 3241., 3919., 4197., 4689., 4983., 4459., 4593., 4605.,
#         4433., 4882., 5308., 5132., 5521., 5100., 4735., 5035., 5106.,
#         5223., 5461., 5324., 5365., 5255., 5195., 5506., 5282., 4996.,
#         4607., 4769., 4657., 4415., 4229., 3689., 3679., 3540., 3346.,
#         3205., 3133., 3041., 2827., 2696., 2526., 2579., 2522., 2380.,
#         2188., 2148., 2075., 1916., 1887., 1789., 1902., 1892., 1898.,
#         1880., 1855., 1738., 1581., 1616., 1625., 1496., 1447., 1412.,
#         1362., 1415., 1383., 1252., 1330., 1418., 1143., 1112., 1269.,
#         1146., 1150.,  951.,  845.,  736.,  672.,  613.,  588.,  576.,
#          558.,  442.,  369.,  347.,  329.,  296.,  220.,  229.,  223.,
#          196.,  198.,  191.,  175.,  187.,  164.,  168.,  155.,  157.,
# ...

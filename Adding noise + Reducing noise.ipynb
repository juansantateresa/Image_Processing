# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from skimage import color, data, io

# %%
from skimage.util import random_noise

# %%
fruit_image = plt.imread(
'/Users/juansantateresagomez/Desktop/Image_Processing/Image Processing with Python course exercise dataset/chapter 3/fruits_square.jpg')

# %%
io.imshow(fruit_image)

# %% [markdown]
# Adding noise

# %%
fruit_image
# Out:
# array([[[109,  38,  78],
#         [130,  58,  98],
#         [111,  35,  74],
#         ...,
#         [188, 185, 178],
#         [182, 179, 172],
#         [202, 203, 197]],
#
#        [[112,  41,  81],
#         [132,  60, 100],
#         [123,  45,  85],
#         ...,
#         [195, 192, 185],
#         [184, 181, 174],
#         [195, 196, 190]],
#
#        [[ 96,  28,  67],
#         [119,  47,  85],
#         [135,  54,  95],
#         ...,
#         [194, 191, 184],
#         [183, 180, 173],
#         [193, 194, 188]],
#
#        ...,
#
#        [[255, 187,  68],
#         [255, 196,  85],
#         [255, 200,  98],
#         ...,
#         [172, 172, 170],
#         [170, 170, 168],
#         [167, 169, 166]],
#
#        [[240, 152,  46],
#         [255, 175,  73],
#         [254, 180,  81],
#         ...,
#         [166, 166, 164],
#         [159, 159, 157],
#         [165, 167, 164]],
#
#        [[255, 118,   3],
#         [255, 131,   0],
#         [250, 150,   0],
# ...

# %%
noisy_fruit = random_noise(fruit_image)

# %%
io.imshow(noisy_fruit)

# %% [markdown]
# Reducing noise

# %%
noisy_dog = plt.imread(
    '/Users/juansantateresagomez/Desktop/Image_Processing/Image Processing with Python course exercise dataset/chapter 3/miny.jpeg')

# %%
io.imshow(noisy_dog)

# %%
from skimage.restoration import denoise_tv_chambolle

# %%
denoise_dog = denoise_tv_chambolle(noisy_dog,eps=0.0002, multichannel=True )

# %%
io.imshow(denoise_dog)

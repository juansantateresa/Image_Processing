# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage import data, io, color

# %%
from skimage.transform import resize

# %%
dogs_banner = plt.imread('Image Processing with Python course exercise dataset/chapter 2/dogs_banner.jpg')

# %%
io.imshow(dogs_banner)

# %%
new_shape = (dogs_banner.shape)

# %%
new_shape
# Out:
# (423, 640, 3)

# %%
height = int(211.5)
width = int(320)

# %%
image_resized = resize(dogs_banner, (height, width), anti_aliasing = True)

# %%
io.imshow(image_resized)
